# %% [markdown]
# Import Libraries

# %%
import numpy as np

# %%
import pandas as pd

# %% [markdown]
# createe pandas series

# %%
a={'a':1,'b':2,'c':3}
ser=pd.Series(data=a)
ser
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
a={'a':1,'b':2,'c':3}
ser=pd.Series(data=a,index=['a','z','y'])
ser
# Out:
# a    1.0
# z    NaN
# y    NaN
# dtype: float64

# %%
l=['banana',12]
s=pd.Series(data=l)
s
# Out:
# 0    banana
# 1        12
# dtype: object

# %%
s=pd.Series(['wes mckiney','creator of pandas'],index=['person','who'])
s
# Out:
# person          wes mckiney
# who       creator of pandas
# dtype: object

# %%
list_of_items=['pens','papers','fruits','vegetables']
product=pd.Series(list_of_items,index=['1','2','3','4'])
product
# Out:
# 1          pens
# 2        papers
# 3        fruits
# 4    vegetables
# dtype: object

# %% [markdown]
# create DataFrame

# %%
a={'col1':[1,2],'col2':[3,4]}
df=pd.DataFrame(data=a)
df
# Out:
#    col1  col2
# 0     1     3
# 1     2     4

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
sudet_details=pd.DataFrame({
'Name':['Soubhagini Das','Kirtimayee Mohanty','Smruti Sagarika'],
'age':[23,21,22],
'Branch':['MCA','MCA','MCA'],
'Py_Marks':[85,87,88]})
print(sudet_details)
# Out:
#                  Name  age Branch  Py_Marks
# 0      Soubhagini Das   23    MCA        85
# 1  Kirtimayee Mohanty   21    MCA        87
# 2     Smruti Sagarika   22    MCA        88

# %%
productdf=pd.DataFrame([['10kg','20kg','30kg','40kg'],[20,30,40,50]],columns=['apple','banana','jackfruit','papaya'])
print(productdf)
# Out:
#   apple banana jackfruit papaya
# 0  10kg   20kg      30kg   40kg
# 1    20     30        40     50

# %% [markdown]
# Attributes

# %%
productdf.shape
# Out:
# (2, 4)

# %%
productdf.size
# Out:
# 8

# %%
productdf.keys()
# Out:
# Index(['apple', 'banana', 'jackfruit', 'papaya'], dtype='object')

# %%
productdf.columns
# Out:
# Index(['apple', 'banana', 'jackfruit', 'papaya'], dtype='object')

# %% [markdown]
# adding columns

# %%
productdf['coconut']=['15kg',10]
productdf
# Out:
#   apple banana jackfruit papaya coconut
# 0  10kg   20kg      30kg   40kg    15kg
# 1    20     30        40     50      10

# %% [markdown]
# Drop columns from the dataframes

# %%
df1=productdf.drop('jackfruit',axis=1)
df1
# Out:
#   apple banana papaya coconut
# 0  10kg   20kg   40kg    15kg
# 1    20     30     50      10

# %%
df1=productdf.drop(columns=['jackfruit'])
df1
# Out:
#   apple banana papaya coconut
# 0  10kg   20kg   40kg    15kg
# 1    20     30     50      10

# %%
df1=productdf.drop(columns=['jackfruit','apple'])
df1
# Out:
#   banana papaya coconut
# 0   20kg   40kg    15kg
# 1     30     50      10

# %%
df1=productdf.drop(columns=['apple'])
df1
# Out:
#   banana jackfruit papaya coconut
# 0   20kg      30kg   40kg    15kg
# 1     30        40     50      10

# %% [markdown]
# Drop rows from the data frame

# %%
df2=productdf.drop(index=[0])
df2
# Out:
#   apple banana jackfruit papaya coconut
# 1    20     30        40     50      10

# %% [markdown]
# combinig frames

# %% [markdown]
# Append

# %%
productdf1=pd.DataFrame([[11,34,56,23],[20,30,40,50]],columns=['apple','banana','jackfruit','papaya'])
productdf1
# Out:
#    apple  banana  jackfruit  papaya
# 0     11      34         56      23
# 1     20      30         40      50

# %%
df3=productdf.append(productdf1)
print(df3)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14244\1011196027.py in ?()
# ----> 1 df3=productdf.append(productdf1)
#       2 print(df3)
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6200             and name not in self._accessors
#    6201             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %%
productdf2=pd.DataFrame([[11,34,56,23],[20,30,40,50]],columns=['apple','banana','jackfruit','papaya'])
productdf2
# Out:
#    apple  banana  jackfruit  papaya
# 0     11      34         56      23
# 1     20      30         40      50

# %%
productdf.append(productdf2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14244\4009952830.py in ?()
# ----> 1 productdf.append(productdf2)
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6200             and name not in self._accessors
#    6201             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %% [markdown]
# concatenate

# %%
india_weather=pd.DataFrame({
"city":['mumbai','delhi','banglore'],
"temperature":[32,40,45],
"humidity":[80,60,70]})
print(india_weather)
# Out:
#        city  temperature  humidity
# 0    mumbai           32        80
# 1     delhi           40        60
# 2  banglore           45        70

# %%
us_weather=pd.DataFrame({
"city":['new york','chicago','orlando'],
"temperature":[32,40,45],
"humidity":[80,60,70]})
print(us_weather)
# Out:
#        city  temperature  humidity
# 0  new york           32        80
# 1   chicago           40        60
# 2   orlando           45        70

# %%
df=pd.concat([india_weather,us_weather])
df
# Out:
#        city  temperature  humidity
# 0    mumbai           32        80
# 1     delhi           40        60
# 2  banglore           45        70
# 0  new york           32        80
# 1   chicago           40        60
# 2   orlando           45        70

# %%
df=pd.concat([india_weather,us_weather],ignore_index=True)
df
# Out:
#        city  temperature  humidity
# 0    mumbai           32        80
# 1     delhi           40        60
# 2  banglore           45        70
# 3  new york           32        80
# 4   chicago           40        60
# 5   orlando           45        70

# %%
df=pd.concat([india_weather,us_weather],axis=0)
df
# Out:
#        city  temperature  humidity
# 0    mumbai           32        80
# 1     delhi           40        60
# 2  banglore           45        70
# 0  new york           32        80
# 1   chicago           40        60
# 2   orlando           45        70

# %%
temperature_df=pd.DataFrame({
"city":["mumbai","delhi","banglore","hyderabad"],
"temperature":[32,45,30,40]})
temperature_df
# Out:
#         city  temperature
# 0     mumbai           32
# 1      delhi           45
# 2   banglore           30
# 3  hyderabad           40

# %%
humidity_df=pd.DataFrame({
"city":["mumbai","delhi","banglore"],
'humidity':[32,45,30]})
humidity_df
# Out:
#        city  humidity
# 0    mumbai        32
# 1     delhi        45
# 2  banglore        30

# %%
df=pd.merge(temperature_df,humidity_df,on='city')
df
# Out:
#        city  temperature  humidity
# 0    mumbai           32        32
# 1     delhi           45        45
# 2  banglore           30        30

# %%
df=pd.merge(temperature_df,humidity_df,on='city',how='outer')
df
# Out:
#        city  temperature  humidity
# 0    mumbai           32        32
# 1     delhi           45        45
# 2  banglore           30        30

# %% [markdown]
# Import Data

# %%
df=pd.read_csv("C:\\Users\\soubh\\Downloads\\archive (1).zip")
df.head()
# Out:
#    work_year experience_level employment_type               job_title  salary  \
# 0       2022               EN              FT   Cyber Program Manager   63000
# 1       2022               MI              FT        Security Analyst   95000
# 2       2022               MI              FT        Security Analyst   70000
# 3       2022               MI              FT     IT Security Analyst  250000
# 4       2022               EN              CT  Cyber Security Analyst  120000
#
#   salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0             USD          63000                 US            50
# 1             USD          95000                 US             0
# 2             USD          70000                 US             0
# 3             BRL          48853                 BR            50
# 4             USD         120000                 BW           100
#
#   company_location company_size
# 0               US            S
# 1               US            M
# ...

# %%
df.head()
# Out:
#    work_year experience_level employment_type               job_title  salary  \
# 0       2022               EN              FT   Cyber Program Manager   63000
# 1       2022               MI              FT        Security Analyst   95000
# 2       2022               MI              FT        Security Analyst   70000
# 3       2022               MI              FT     IT Security Analyst  250000
# 4       2022               EN              CT  Cyber Security Analyst  120000
#
#   salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0             USD          63000                 US            50
# 1             USD          95000                 US             0
# 2             USD          70000                 US             0
# 3             BRL          48853                 BR            50
# 4             USD         120000                 BW           100
#
#   company_location company_size
# 0               US            S
# 1               US            M
# ...

# %%
df.tail()
# Out:
#       work_year experience_level employment_type  \
# 1242       2020               MI              FT
# 1243       2021               SE              FT
# 1244       2021               SE              FT
# 1245       2021               MI              FT
# 1246       2021               MI              FT
#
#                          job_title  salary salary_currency  salary_in_usd  \
# 1242        Cyber Security Analyst  140000             AUD          96422
# 1243  Information Security Manager   60000             GBP          82528
# 1244  Penetration Testing Engineer  126000             USD         126000
# 1245  Information Security Analyst   42000             GBP          57769
# 1246   Threat Intelligence Analyst   66310             USD          66310
#
#      employee_residence  remote_ratio company_location company_size
# 1242                 AU            50               AU            M
# 1243                 GB            50               GB            L
# ...

# %%
df.shape
# Out:
# (1247, 11)

# %%
df.size
# Out:
# 13717

# %%
df.columns
# Out:
# Index(['work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary', 'salary_currency', 'salary_in_usd', 'employee_residence',
#        'remote_ratio', 'company_location', 'company_size'],
#       dtype='object')

# %%
df.dtypes
# Out:
# work_year              int64
# experience_level      object
# employment_type       object
# job_title             object
# salary                 int64
# salary_currency       object
# salary_in_usd          int64
# employee_residence    object
# remote_ratio           int64
# company_location      object
# company_size          object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1247 entries, 0 to 1246
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           1247 non-null   int64
#  1   experience_level    1247 non-null   object
#  2   employment_type     1247 non-null   object
#  3   job_title           1247 non-null   object
#  4   salary              1247 non-null   int64
#  5   salary_currency     1247 non-null   object
#  6   salary_in_usd       1247 non-null   int64
#  7   employee_residence  1247 non-null   object
#  8   remote_ratio        1247 non-null   int64
#  9   company_location    1247 non-null   object
#  10  company_size        1247 non-null   object
# dtypes: int64(4), object(7)
# memory usage: 107.3+ KB

# %%
df.isnull().sum()
# Out:
# work_year             0
# experience_level      0
# employment_type       0
# job_title             0
# salary                0
# salary_currency       0
# salary_in_usd         0
# employee_residence    0
# remote_ratio          0
# company_location      0
# company_size          0
# dtype: int64

# %%
df.describe()
# Out:
#          work_year        salary  salary_in_usd  remote_ratio
# count  1247.000000  1.247000e+03    1247.000000   1247.000000
# mean   2021.316760  5.608525e+05  120278.218925     71.491580
# std       0.715501  1.415944e+07   70291.394942     39.346851
# min    2020.000000  1.740000e+03    2000.000000      0.000000
# 25%    2021.000000  7.975450e+04   74594.500000     50.000000
# 50%    2021.000000  1.200000e+05  110000.000000    100.000000
# 75%    2022.000000  1.600800e+05  150000.000000    100.000000
# max    2022.000000  5.000000e+08  910991.000000    100.000000

# %%
df.describe(include="all")
# Out:
#           work_year experience_level employment_type          job_title  \
# count   1247.000000             1247            1247               1247
# unique          NaN                4               4                 87
# top             NaN               SE              FT  Security Engineer
# freq            NaN              547            1225                194
# mean    2021.316760              NaN             NaN                NaN
# std        0.715501              NaN             NaN                NaN
# min     2020.000000              NaN             NaN                NaN
# 25%     2021.000000              NaN             NaN                NaN
# 50%     2021.000000              NaN             NaN                NaN
# 75%     2022.000000              NaN             NaN                NaN
# max     2022.000000              NaN             NaN                NaN
#
#               salary salary_currency  salary_in_usd employee_residence  \
# ...

# %%
print(df.describe())
# Out:
#          work_year        salary  salary_in_usd  remote_ratio
# count  1247.000000  1.247000e+03    1247.000000   1247.000000
# mean   2021.316760  5.608525e+05  120278.218925     71.491580
# std       0.715501  1.415944e+07   70291.394942     39.346851
# min    2020.000000  1.740000e+03    2000.000000      0.000000
# 25%    2021.000000  7.975450e+04   74594.500000     50.000000
# 50%    2021.000000  1.200000e+05  110000.000000    100.000000
# 75%    2022.000000  1.600800e+05  150000.000000    100.000000
# max    2022.000000  5.000000e+08  910991.000000    100.000000

# %% [markdown]
# Single Column

# %%
df['work_year']
# Out:
# 0       2022
# 1       2022
# 2       2022
# 3       2022
# 4       2022
#         ...
# 1242    2020
# 1243    2021
# 1244    2021
# 1245    2021
# 1246    2021
# Name: work_year, Length: 1247, dtype: int64

# %%
df.employment_type
# Out:
# 0       FT
# 1       FT
# 2       FT
# 3       FT
# 4       CT
#         ..
# 1242    FT
# 1243    FT
# 1244    FT
# 1245    FT
# 1246    FT
# Name: employment_type, Length: 1247, dtype: object

# %% [markdown]
# Multiple Columns

# %%
df[['employment_type','work_year']]
# Out:
#      employment_type  work_year
# 0                 FT       2022
# 1                 FT       2022
# 2                 FT       2022
# 3                 FT       2022
# 4                 CT       2022
# ...              ...        ...
# 1242              FT       2020
# 1243              FT       2021
# 1244              FT       2021
# 1245              FT       2021
# 1246              FT       2021
#
# [1247 rows x 2 columns]

# %%
df['remote_ratio'].values
# Out:
# array([ 50,   0,   0, ..., 100, 100,   0], dtype=int64)

# %%
df
# Out:
#       work_year experience_level employment_type  \
# 0          2022               EN              FT
# 1          2022               MI              FT
# 2          2022               MI              FT
# 3          2022               MI              FT
# 4          2022               EN              CT
# ...         ...              ...             ...
# 1242       2020               MI              FT
# 1243       2021               SE              FT
# 1244       2021               SE              FT
# 1245       2021               MI              FT
# 1246       2021               MI              FT
#
#                          job_title  salary salary_currency  salary_in_usd  \
# 0            Cyber Program Manager   63000             USD          63000
# 1                 Security Analyst   95000             USD          95000
# 2                 Security Analyst   70000             USD          70000
# 3              IT Security Analyst  250000             BRL          48853
# ...

# %%
df["half_salary"]=df["salary"]/2
df
# Out:
#       work_year experience_level employment_type  \
# 0          2022               EN              FT
# 1          2022               MI              FT
# 2          2022               MI              FT
# 3          2022               MI              FT
# 4          2022               EN              CT
# ...         ...              ...             ...
# 1242       2020               MI              FT
# 1243       2021               SE              FT
# 1244       2021               SE              FT
# 1245       2021               MI              FT
# 1246       2021               MI              FT
#
#                          job_title  salary salary_currency  salary_in_usd  \
# 0            Cyber Program Manager   63000             USD          63000
# 1                 Security Analyst   95000             USD          95000
# 2                 Security Analyst   70000             USD          70000
# 3              IT Security Analyst  250000             BRL          48853
# ...

# %%
df.drop("half_salary",axis=1,inplace=True)
df
# Out:
#       work_year experience_level employment_type  \
# 0          2022               EN              FT
# 1          2022               MI              FT
# 2          2022               MI              FT
# 3          2022               MI              FT
# 4          2022               EN              CT
# ...         ...              ...             ...
# 1242       2020               MI              FT
# 1243       2021               SE              FT
# 1244       2021               SE              FT
# 1245       2021               MI              FT
# 1246       2021               MI              FT
#
#                          job_title  salary salary_currency  salary_in_usd  \
# 0            Cyber Program Manager   63000             USD          63000
# 1                 Security Analyst   95000             USD          95000
# 2                 Security Analyst   70000             USD          70000
# 3              IT Security Analyst  250000             BRL          48853
# ...

# %% [markdown]
# Selecting Perticular rows and Columns

# %%
df.iloc[0] #get the 1st row
# Out:
# work_year                              2022
# experience_level                         EN
# employment_type                          FT
# job_title             Cyber Program Manager
# salary                                63000
# salary_currency                         USD
# salary_in_usd                         63000
# employee_residence                       US
# remote_ratio                             50
# company_location                         US
# company_size                              S
# Name: 0, dtype: object

# %%
df.iloc[99] #get the 100th row
# Out:
# work_year                            2022
# experience_level                       SE
# employment_type                        FT
# job_title             Security Specialist
# salary                             153600
# salary_currency                       USD
# salary_in_usd                      153600
# employee_residence                     US
# remote_ratio                          100
# company_location                       US
# company_size                            L
# Name: 99, dtype: object

# %%
df.iloc[1250]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 df.iloc[1250]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1153, in _LocationIndexer.__getitem__(self, key)
#    1150 axis = self.axis or 0
#    1152 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1153 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1714, in _iLocIndexer._getitem_axis(self, key, axis)
#    1711     raise TypeError("Cannot index by location index with a non-integer key")
#    1713 # validate the location
# -> 1714 self._validate_integer(key, axis)
#    1716 return self.obj._ixs(key, axis=axis)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1647, in _iLocIndexer._validate_integer(self, key, axis)
#    1645 len_axis = len(self.obj._get_axis(axis))
# ...

# %%
df.iloc[[0,99]]
# Out:
#     work_year experience_level employment_type              job_title  salary  \
# 0        2022               EN              FT  Cyber Program Manager   63000
# 99       2022               SE              FT    Security Specialist  153600
#
#    salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0              USD          63000                 US            50
# 99             USD         153600                 US           100
#
#    company_location company_size
# 0                US            S
# 99               US            L

# %%
#select the 4th row & 3rd column
df.iloc[3,2]
# Out:
# 'FT'

# %%
#displaying nmultiple specified columns and rows
df.iloc[[5,9],[1,4]]
# Out:
#   experience_level  salary
# 5               EX  315000
# 9               EX  360000

# %%
#displaying specified columns of range of rows
df.iloc[5:9,[4]]
# Out:
#    salary
# 5  315000
# 6  220000
# 7  140000
# 8   55000

# %%
print(df.loc[0])
# Out:
# work_year                              2022
# experience_level                         EN
# employment_type                          FT
# job_title             Cyber Program Manager
# salary                                63000
# salary_currency                         USD
# salary_in_usd                         63000
# employee_residence                       US
# remote_ratio                             50
# company_location                         US
# company_size                              S
# Name: 0, dtype: object

# %%
print(df.loc[99])
# Out:
# work_year                            2022
# experience_level                       SE
# employment_type                        FT
# job_title             Security Specialist
# salary                             153600
# salary_currency                       USD
# salary_in_usd                      153600
# employee_residence                     US
# remote_ratio                          100
# company_location                       US
# company_size                            L
# Name: 99, dtype: object

# %%
print(df.loc[-1])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\range.py:414, in RangeIndex.get_loc(self, key)
#     413 try:
# --> 414     return self._range.index(new_key)
#     415 except ValueError as err:
#
# ValueError: -1 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 print(df.loc[-1])
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1153, in _LocationIndexer.__getitem__(self, key)
#    1150 axis = self.axis or 0
#    1152 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1153 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1393, in _LocIndexer._getitem_axis(self, key, axis)
# ...

# %%
df.tail()
# Out:
#       work_year experience_level employment_type  \
# 1242       2020               MI              FT
# 1243       2021               SE              FT
# 1244       2021               SE              FT
# 1245       2021               MI              FT
# 1246       2021               MI              FT
#
#                          job_title  salary salary_currency  salary_in_usd  \
# 1242        Cyber Security Analyst  140000             AUD          96422
# 1243  Information Security Manager   60000             GBP          82528
# 1244  Penetration Testing Engineer  126000             USD         126000
# 1245  Information Security Analyst   42000             GBP          57769
# 1246   Threat Intelligence Analyst   66310             USD          66310
#
#      employee_residence  remote_ratio company_location company_size
# 1242                 AU            50               AU            M
# 1243                 GB            50               GB            L
# ...

# %%
df.loc[543]
# Out:
# work_year                                     2021
# experience_level                                MI
# employment_type                                 FT
# job_title             Information Security Analyst
# salary                                       98000
# salary_currency                                USD
# salary_in_usd                                98000
# employee_residence                              US
# remote_ratio                                   100
# company_location                                US
# company_size                                     L
# Name: 543, dtype: object

# %%
df.loc[1:5,]
# Out:
#    work_year experience_level employment_type                       job_title  \
# 1       2022               MI              FT                Security Analyst
# 2       2022               MI              FT                Security Analyst
# 3       2022               MI              FT             IT Security Analyst
# 4       2022               EN              CT          Cyber Security Analyst
# 5       2022               EX              FT  Application Security Architect
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 1   95000             USD          95000                 US             0
# 2   70000             USD          70000                 US             0
# 3  250000             BRL          48853                 BR            50
# 4  120000             USD         120000                 BW           100
# 5  315000             USD         315000                 US           100
#
#   company_location company_size
# ...

# %%
df.loc[[1,5,6],'work_year':'job_title']
# Out:
#    work_year experience_level employment_type                       job_title
# 1       2022               MI              FT                Security Analyst
# 5       2022               EX              FT  Application Security Architect
# 6       2022               SE              FT             Security Researcher

# %%
df.loc[1,'work_year']
# Out:
# 2022

# %%
df.iloc[4,3]
# Out:
# 'Cyber Security Analyst'

# %%
df.iloc[[0,99,499],[0,3,5]]
# Out:
#      work_year                  job_title salary_currency
# 0         2022      Cyber Program Manager             USD
# 99        2022        Security Specialist             USD
# 499       2022  Cyber Security Specialist             EUR

# %% [markdown]
# setindex

# %%
l1=df.set_index("job_title")
l1.head()
# Out:
#                         work_year experience_level employment_type  salary  \
# job_title
# Cyber Program Manager        2022               EN              FT   63000
# Security Analyst             2022               MI              FT   95000
# Security Analyst             2022               MI              FT   70000
# IT Security Analyst          2022               MI              FT  250000
# Cyber Security Analyst       2022               EN              CT  120000
#
#                        salary_currency  salary_in_usd employee_residence  \
# job_title
# Cyber Program Manager              USD          63000                 US
# Security Analyst                   USD          95000                 US
# Security Analyst                   USD          70000                 US
# IT Security Analyst                BRL          48853                 BR
# Cyber Security Analyst             USD         120000                 BW
#
# ...

# %%
l1.shape
# Out:
# (1247, 10)

# %%
l1.loc['Security Analyst']
# Out:
#                   work_year experience_level employment_type  salary  \
# job_title
# Security Analyst       2022               MI              FT   95000
# Security Analyst       2022               MI              FT   70000
# Security Analyst       2022               MI              FT  115000
# Security Analyst       2022               MI              FT  114000
# Security Analyst       2022               EN              FT  140000
# Security Analyst       2022               EN              FT   63000
# Security Analyst       2022               MI              FT   89000
# Security Analyst       2022               MI              FT   68462
# Security Analyst       2022               MI              FT  102600
# Security Analyst       2022               MI              FT   82080
# Security Analyst       2022               MI              FT  193800
# Security Analyst       2022               MI              FT   62000
# ...

# %%
l1.loc['Security Analyst','work_year':'salary']
# Out:
#                   work_year experience_level employment_type  salary
# job_title
# Security Analyst       2022               MI              FT   95000
# Security Analyst       2022               MI              FT   70000
# Security Analyst       2022               MI              FT  115000
# Security Analyst       2022               MI              FT  114000
# Security Analyst       2022               EN              FT  140000
# Security Analyst       2022               EN              FT   63000
# Security Analyst       2022               MI              FT   89000
# Security Analyst       2022               MI              FT   68462
# Security Analyst       2022               MI              FT  102600
# Security Analyst       2022               MI              FT   82080
# Security Analyst       2022               MI              FT  193800
# Security Analyst       2022               MI              FT   62000
# ...

# %%
l1.reset_index()
# Out:
#                          job_title  work_year experience_level  \
# 0            Cyber Program Manager       2022               EN
# 1                 Security Analyst       2022               MI
# 2                 Security Analyst       2022               MI
# 3              IT Security Analyst       2022               MI
# 4           Cyber Security Analyst       2022               EN
# ...                            ...        ...              ...
# 1242        Cyber Security Analyst       2020               MI
# 1243  Information Security Manager       2021               SE
# 1244  Penetration Testing Engineer       2021               SE
# 1245  Information Security Analyst       2021               MI
# 1246   Threat Intelligence Analyst       2021               MI
#
#      employment_type  salary salary_currency  salary_in_usd  \
# 0                 FT   63000             USD          63000
# 1                 FT   95000             USD          95000
# ...

# %%
l1.reset_index()
# Out:
#                          job_title  work_year experience_level  \
# 0            Cyber Program Manager       2022               EN
# 1                 Security Analyst       2022               MI
# 2                 Security Analyst       2022               MI
# 3              IT Security Analyst       2022               MI
# 4           Cyber Security Analyst       2022               EN
# ...                            ...        ...              ...
# 1242        Cyber Security Analyst       2020               MI
# 1243  Information Security Manager       2021               SE
# 1244  Penetration Testing Engineer       2021               SE
# 1245  Information Security Analyst       2021               MI
# 1246   Threat Intelligence Analyst       2021               MI
#
#      employment_type  salary salary_currency  salary_in_usd  \
# 0                 FT   63000             USD          63000
# 1                 FT   95000             USD          95000
# ...

# %%
df['job_title'].value_counts()
# Out:
# job_title
# Security Engineer                          194
# Cyber Security Analyst                     133
# Penetration Tester                          70
# Information Security Manager                64
# Cyber Security Engineer                     63
#                                           ...
# Principal Application Security Engineer      1
# Application Security Specialist              1
# Information Security Compliance Analyst      1
# Application Security Architect               1
# Concierge Security Engineer                  1
# Name: count, Length: 87, dtype: int64

# %%
df['job_title'].value_counts()/len(df['job_title'])
# Out:
# job_title
# Security Engineer                          0.155573
# Cyber Security Analyst                     0.106656
# Penetration Tester                         0.056135
# Information Security Manager               0.051323
# Cyber Security Engineer                    0.050521
#                                              ...
# Principal Application Security Engineer    0.000802
# Application Security Specialist            0.000802
# Information Security Compliance Analyst    0.000802
# Application Security Architect             0.000802
# Concierge Security Engineer                0.000802
# Name: count, Length: 87, dtype: float64

# %%
df['job_title'].value_counts(normalize=True)
# Out:
# job_title
# Security Engineer                          0.155573
# Cyber Security Analyst                     0.106656
# Penetration Tester                         0.056135
# Information Security Manager               0.051323
# Cyber Security Engineer                    0.050521
#                                              ...
# Principal Application Security Engineer    0.000802
# Application Security Specialist            0.000802
# Information Security Compliance Analyst    0.000802
# Application Security Architect             0.000802
# Concierge Security Engineer                0.000802
# Name: proportion, Length: 87, dtype: float64

# %%
df['salary'].mean()
# Out:
# 560852.4883720931

# %%
df['salary'].median()
# Out:
# 120000.0

# %%
df['salary'].max()
# Out:
# 500000000

# %%
df['salary'].sum()
# Out:
# 699383053

# %%
df['salary'].product()
# Out:
# 0

# %%
df['salary'].nsmallest()
# Out:
# 1122    1740
# 437     2000
# 961     2000
# 483     2202
# 379     5800
# Name: salary, dtype: int64

# %%
df['salary'].nlargest()
# Out:
# 616     500000000
# 868      10320000
# 1063      3800000
# 977       3600000
# 785       3200000
# Name: salary, dtype: int64

# %% [markdown]
# Sort Function

# %%
df.sort_values(by='salary',ascending=False)
# Out:
#       work_year experience_level employment_type  \
# 616        2022               SE              FT
# 868        2021               MI              FT
# 1063       2021               EX              FT
# 977        2021               MI              FT
# 786        2021               MI              FT
# ...         ...              ...             ...
# 379        2022               EN              FT
# 483        2022               MI              FT
# 961        2021               EN              FT
# 437        2022               EN              FT
# 1122       2021               MI              FT
#
#                           job_title     salary salary_currency  salary_in_usd  \
# 616          Incident Response Lead  500000000             IDR          34432
# 868            IT Security Engineer   10320000             HUF          34018
# 1063    Principal Security Engineer    3800000             INR          51389
# ...

# %%
df.sort_values(by='salary',ascending=True)
# Out:
#       work_year experience_level employment_type  \
# 1122       2021               MI              FT
# 961        2021               EN              FT
# 437        2022               EN              FT
# 483        2022               MI              FT
# 379        2022               EN              FT
# ...         ...              ...             ...
# 786        2021               MI              FT
# 977        2021               MI              FT
# 1063       2021               EX              FT
# 868        2021               MI              FT
# 616        2022               SE              FT
#
#                           job_title     salary salary_currency  salary_in_usd  \
# 1122             Penetration Tester       1740             EUR           2056
# 961   Application Security Engineer       2000             USD           2000
# 437              Penetration Tester       2000             USD           2000
# ...

# %% [markdown]
# Data Extraction

# %%
cyber_security_analytic=df[df["job_title"]=="Cyber Security Analyst"]
cyber_security_analytic
# Out:
#       work_year experience_level employment_type               job_title  \
# 4          2022               EN              CT  Cyber Security Analyst
# 18         2022               EN              FT  Cyber Security Analyst
# 20         2020               EN              FT  Cyber Security Analyst
# 43         2022               MI              FT  Cyber Security Analyst
# 51         2022               EN              FT  Cyber Security Analyst
# ...         ...              ...             ...                     ...
# 1194       2021               EN              FT  Cyber Security Analyst
# 1222       2020               EN              FT  Cyber Security Analyst
# 1233       2020               SE              FT  Cyber Security Analyst
# 1240       2021               EN              FT  Cyber Security Analyst
# 1242       2020               MI              FT  Cyber Security Analyst
#
#       salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# ...

# %%
df[df['salary']>=65000]
# Out:
#       work_year experience_level employment_type  \
# 1          2022               MI              FT
# 2          2022               MI              FT
# 3          2022               MI              FT
# 4          2022               EN              CT
# 5          2022               EX              FT
# ...         ...              ...             ...
# 1240       2021               EN              FT
# 1241       2020               MI              FT
# 1242       2020               MI              FT
# 1244       2021               SE              FT
# 1246       2021               MI              FT
#
#                            job_title  salary salary_currency  salary_in_usd  \
# 1                   Security Analyst   95000             USD          95000
# 2                   Security Analyst   70000             USD          70000
# 3                IT Security Analyst  250000             BRL          48853
# ...

# %% [markdown]
# Logical Operator

# %%
filter1=df[(df['salary']>=65000 & (df['salary']<=85000))]
print("shape  of new dataset using and is:",filter1.shape)
# Out:
# shape  of new dataset using and is: (1247, 11)

# %%
filter1
# Out:
#       work_year experience_level employment_type  \
# 0          2022               EN              FT
# 1          2022               MI              FT
# 2          2022               MI              FT
# 3          2022               MI              FT
# 4          2022               EN              CT
# ...         ...              ...             ...
# 1242       2020               MI              FT
# 1243       2021               SE              FT
# 1244       2021               SE              FT
# 1245       2021               MI              FT
# 1246       2021               MI              FT
#
#                          job_title  salary salary_currency  salary_in_usd  \
# 0            Cyber Program Manager   63000             USD          63000
# 1                 Security Analyst   95000             USD          95000
# 2                 Security Analyst   70000             USD          70000
# 3              IT Security Analyst  250000             BRL          48853
# ...

# %%
filter2=df[(df['salary_currency']=="USD") | (df['salary']<=85000)|(df['salary']<=65000)]
print("shape  of new dataset using and is:",filter2.shape)
# Out:
# shape  of new dataset using and is: (1102, 11)

# %%
filter3
